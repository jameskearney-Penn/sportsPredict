# %% [markdown]
# <a href="https://colab.research.google.com/github/jameskearney-Penn/sportsPredict/blob/main/sports_predict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Sports Predict 
"""
Sports Predict is an analysis of NBA games using 
"""
# Out:
#   File "<ipython-input-1-d6c0ff3e75f5>", line 2
#     """
#        ^
# SyntaxError: EOF while scanning triple-quoted string literal
